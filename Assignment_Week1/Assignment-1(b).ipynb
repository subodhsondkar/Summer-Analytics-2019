# %%
import pandas as pd

# %%
idf = pd.read_csv('iris.csv')

# %%
idf.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
idf.shape
# Out:
# (150, 5)

# %%
idf.var()
# Out:
# SepalLength    0.685694
# SepalWidth     0.188004
# PetalLength    3.113179
# PetalWidth     0.582414
# dtype: float64

# %%
idf2 = pd.DataFrame([[idf.var()['SepalLength'], idf.var()['SepalWidth'], idf.var()['PetalLength'], idf.var()['PetalWidth']]], columns = ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth'], index = ['var'])

# %%
idf1 = idf.describe(percentiles = [0.25, 0.5, 0.75])

# %%
idf4 = pd.concat([idf1, idf2, idf3], axis = 0)

# %%
idf3 = pd.DataFrame([[idf['SepalLength'].max() - idf['SepalLength'].min(), idf['SepalWidth'].max() - idf['SepalWidth'].min(), idf['PetalLength'].max() - idf['PetalLength'].min(), idf['PetalWidth'].max() - idf['PetalWidth'].min()]], columns = ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth'], index = ['range'])

# %%
idf4
# Out:
#        SepalLength  SepalWidth  PetalLength  PetalWidth
# count   150.000000  150.000000   150.000000  150.000000
# mean      5.843333    3.054000     3.758667    1.198667
# std       0.828066    0.433594     1.764420    0.763161
# min       4.300000    2.000000     1.000000    0.100000
# 25%       5.100000    2.800000     1.600000    0.300000
# 50%       5.800000    3.000000     4.350000    1.300000
# 75%       6.400000    3.300000     5.100000    1.800000
# max       7.900000    4.400000     6.900000    2.500000
# var       0.685694    0.188004     3.113179    0.582414
# range     3.600000    2.400000     5.900000    2.400000

# %%
# %matplotlib inline

# %%
idf.plot(kind = 'hist', subplots = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f86707961d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f86707c5b00>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f867076bcf8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f8670719198>],
#       dtype=object)

# %%
idf.plot(kind = 'box')

# %%
pdf = pd.read_csv('pendigits.csv')

# %%
pdf
# Out:
#        47  100   27   81   57   37   26    0    0.1   23   56   53  100.1  \
# 0       0   89   27  100   42   75   29   45     15   15   37    0     69
# 1       0   57   31   68   72   90  100  100     76   75   50   51     28
# 2       0  100    7   92    5   68   19   45     86   34  100   45     74
# 3       0   67   49   83  100  100   81   80     60   60   40   40     33
# 4     100  100   88   99   49   74   17   47      0   16   37    0     73
# 5       0  100    3   72   26   35   85   35    100   71   73   97     65
# 6       0   39    2   62   11    5   63    0    100   43   89   99     36
# 7      13   89   12   50   72   38   56    0      4   17    0   61     32
# 8      57  100   22   72    0   31   25    0     75   13  100   50     75
# 9      74   87   31  100    0   69   62   64    100   79  100   38     84
# 10     48   96   62   65   88   27   21    0     21   33   79   67    100
# 11    100  100   72   99   36   78   34   54     79   47   64   13     19
# 12     91   74   54  100    0   87   23   59     81   67  100   39     79
# 13      0   85   38  100   81   88   87   50     84   12   58    0     53
# 6     100    0   57   0
# 7      94  100  100   5
# 8      87   26   85   0
# 9       0   18    1   9
# 10    100    0   85   8
# 11      0    0    2   5
# 12      4   21    0   9
# 13     22  100   24   7
# 14      0    0   17   3
# 15      0    0    7   3
# 16      0    0   16   9
# 17      0  100    1   2
# 18      0  100    0   2
# 19     98  100  100   5
# 20     24   89    0   1
# 21     95  100  100   5
# 22     57   90   94   8
# 23     46   36   21   6
# 24     33   66    0   4
# 25     89   36  100   0
# 26     27    0    0   4
# 27     44  100   70   8
# 28     17    0    0   1
# 29     55    0   63   8
# ...   ...  ...  ...  ..
# 7463    0    0   14   3
# 7464   30   55    0   7
# 7465   34   69   44   7
# 7466   73    0   24   0
# 7467    0    0   13   3
# 7468    3    0    0   3
# 7469    0    0   17   3
# 7470   25   37    0   1
# 7471    3  100    6   1
# 7472    4  100    7   1
# 7473    1    0    0   3
# 7474   18    0   10   6
# 7475   48    0   76   8
# 7476   27   86    0   4
# 7477    3  100    4   2
# 7478   30  100   33   7
# 7479   25   16   18   6
# 7480   23  100    0   4
# 7481   21   51    0   1
# 7482    1    0    0   9
# 7483    0   47    2   2
# 7484   32    0    0   6
# 7485    0    0    3   3
# 7486    0    0    2   9
# 7487   91    0   52   0
# 7488   96  100  100   5
# 7489   38    6    0   4
# 7490    0    0    5   5
# 7491    1  100    0   1
# 7492   36  100   40   7
#
# [7493 rows x 17 columns]

# %%
pdf.head()
# Out:
#     47  100   27   81   57   37   26    0    0.1   23   56   53  100.1   90  \
# 0    0   89   27  100   42   75   29   45     15   15   37    0     69    2
# 1    0   57   31   68   72   90  100  100     76   75   50   51     28   25
# 2    0  100    7   92    5   68   19   45     86   34  100   45     74   23
# 3    0   67   49   83  100  100   81   80     60   60   40   40     33   20
# 4  100  100   88   99   49   74   17   47      0   16   37    0     73   16
#
#     40   98   8
# 0  100    6   2
# 1   16    0   1
# 2   67    0   4
# 3   47    0   1
# 4   20   20   6

# %%
pdf.shape
# Out:
# (7493, 17)

# %%
pdf1 = pdf.describe(percentiles = [0.25, 0.5, 0.75])

# %%
pdf.columns
# Out:
# Index([' 47', '100', ' 27', ' 81', ' 57', ' 37', ' 26', '  0', '  0.1', ' 23',
#        ' 56', ' 53', '100.1', ' 90', ' 40', ' 98', ' 8'],
#       dtype='object')

# %%
a = []
b = []
c = []
for x in pdf.columns:
    a += [pdf.var()[x]]
    b += [x]
    c += [pdf.max()[x] - pdf.min()[x]]
pdf2 = pd.DataFrame([a, c], columns = b, index = ['var', 'range'])

# %%
pdf3 = pd.concat([pdf1, pdf2], axis = 0)

# %%
pdf3
# Out:
#                 47          100           27           81           57  \
# count  7493.000000  7493.000000  7493.000000  7493.000000  7493.000000
# mean     37.383024    84.677299    40.007340    82.889764    50.877486
# std      33.324063    16.848615    26.257347    19.639880    34.929460
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       5.000000    76.000000    20.000000    70.000000    17.000000
# 50%      31.000000    89.000000    39.000000    89.000000    56.000000
# 75%      61.000000   100.000000    58.000000   100.000000    81.000000
# max     100.000000   100.000000   100.000000   100.000000   100.000000
# var    1110.493155   283.875829   689.448291   385.724899  1220.067209
# range   100.000000   100.000000   100.000000   100.000000   100.000000
#
#                 37           26            0          0.1           23  \
# count  7493.000000  7493.000000  7493.000000  7493.000000  7493.000000
# mean     65.048178    51.475244    44.605632    57.137595    34.070599
# std      27.377250    30.680711    30.657194    33.676120    27.461524
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%      48.000000    28.000000    22.000000    30.000000     7.000000
# 50%      71.000000    54.000000    42.000000    60.000000    33.000000
# 75%      86.000000    75.000000    65.000000    88.000000    55.000000
# max     100.000000   100.000000   100.000000   100.000000   100.000000
# var     749.513829   941.306014   939.863540  1134.081038   754.135298
# range   100.000000   100.000000   100.000000   100.000000   100.000000
#
#                 56           53        100.1           90           40  \
# count  7493.000000  7493.000000  7493.000000  7493.000000  7493.000000
# mean     61.418124    35.779794    54.693714    35.793541    46.814627
# std      37.133187    27.496951    22.595228    33.219926    41.534491
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%      25.000000    12.000000    41.000000     7.000000     0.000000
# 50%      74.000000    32.000000    53.000000    28.000000    39.000000
# 75%      98.000000    57.000000    69.000000    48.000000   100.000000
# max     100.000000   100.000000   100.000000   100.000000   100.000000
# var    1378.873601   756.082309   510.544324  1103.563482  1725.113924
# range   100.000000   100.000000   100.000000   100.000000   100.000000
#
#                 98            8
# count  7493.000000  7493.000000
# mean     28.556119     4.430402
# std      35.804498     2.876877
# min       0.000000     0.000000
# 25%       0.000000     2.000000
# 50%       8.000000     4.000000
# 75%      51.000000     7.000000
# max     100.000000     9.000000
# var    1281.962046     8.276422
# range   100.000000     9.000000

# %%
pdf.plot(kind = 'hist')

# %%
pdf.plot(kind = 'box')

# %% [markdown]
# # QUESTIONS
#     a.) Consider the histograms you generated for the Iris dataset.
#         i) How do the shapes of the histograms for petal length and petal width differ from those for sepal             length and sepal width?
#         ii) Now consider just the petal width histogram. Is there a particular value of petal length (which ranges from 1.0 to 6.9) where the distribution of petal lengths (as illustrated by the histogram) could be best segmented into two parts?
#         iii) Now consider the boxplots you generated for the Iris dataset. There should be four boxplots, one for each feature. Based upon these boxplots, is there a pair of features that appear to have significantly different medians?
#         iv) Recall that the degree of overlap between variabilities is an important initial indicator of the likelihood that differences in means or medians are meaningful. Also, based solely upon the box plots, which feature appears to explain the greatest amount of the data?
#     b.) Lastly, consider the boxplots you generated for the Digits dataset.
#         i) Do you observe any outliers? If so, for what features?
#         ii) Now consider the corresponding histograms. What sort of distribution do the second and forth features display?
#         iii) With that in mind, explain the outliers, or lack thereof, in terms of what you observe from the histograms.

# %% [markdown]
# # (a) (i)
#     PetalWidth has a uniform graph. PetalLength is a bimodal graph. Comparatively, SepalLength and SepalWidth have unimodal graphs.

# %% [markdown]
# # (a) (ii)
#     Yes, the median of the PetalLength graph.

# %% [markdown]
# # (a) (iii)
#     Yes, SepalLength and PetalWidth.

# %% [markdown]
# # (a) (iv)
#     PetalLength.

# %% [markdown]
# # (b) (i)
#     Yes, for 100 and 81.

# %% [markdown]
# # (b) (ii)
#     Curvilinear increasing (left skewed).

# %% [markdown]
# # (b) (iii)
#     Outliers consist of data points on the far left in both the graphs.
